# %% [markdown]
# ## Aprendizaje automático
# ### Tópicos en Aprendizaje Automático
#
#
# Integrantes: +Sigrid Segura +Víctor Garro Abarca
#
#
# ---
#
#
#
# Resumen: En este trabajo se hará un estudio teórico con ejemplos prácticos del tema asignado, sobre una de las tendencias  en el ámbito del aprendizaje automático
#
#
# ---

# %% [markdown]
# ### CONTENIDO
#
# > WEKA
# * Características
# * Instalación e interfaz
# * Ficheros .arff
#
# > EJERCICIOS
# * Ejercicio 1: Preprocesado
# * Ejercicio 2: Visualización
# * Ejercicio 3: Filtros
#
# ---

# %% [markdown]
# # WEKA

# %% [markdown]
# Weka (Waikato Environment for Knowledge Analysis, en español «entorno para análisis del conocimiento de la Universidad de Waikato») es una plataforma de software para el aprendizaje automático y la minería de datos escrito en Java y desarrollado en la Universidad de Waikato (Nueva Zelanda).
#
# El paquete contiene una colección de herramientas de visualización y algoritmos para análisis de datos y modelado predictivo, unidos a una interfaz gráfica de usuario para acceder fácilmente a sus funcionalidades. Es decir, Weka contiene las herramientas necesarias para realizar transformaciones sobre los datos, tareas de clasificación, regresión, clustering, asociación y visualización. Weka está diseñado como una herramienta orientada a la extensibilidad por lo que añadir nuevas funcionalidades es una tarea sencilla.
#
# Sin embargo, y pese a todas las cualidades que Weka posee, tiene un gran defecto y éste es la escasa documentación orientada al usuario, lo que la hace una herramienta díficil de comprender y manejar sin información adicional.

# %% [markdown]
# ![Captura de pantalla-20220522185457-499x313.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Características de Weka
#
# Algunas de las principales características de Weka:
#
# * Está disponible libremente bajo la licencia pública general de GNU.
# * Es muy portable porque está completamente implementado en Java y puede correr en casi cualquier plataforma.
# * Contiene una extensa colección de técnicas para preprocesamiento de datos y modelado.
# * Es fácil de utilizar por un principiante gracias a su interfaz gráfica de usuario.
#
# Se observan varias aplicaciones o módulos: `Explorer`, `Experimenter`, `KnowledgeFlow`, `Workbench` y `Simple CLI`.
#
# El Explorer es el de uso más común, y el que se utilizará en esta sesión práctica. Es un módulo que permite acceder a un set de datos y realizar procesos de Data Mining (visualizarlo, aplicarle alguna técnica de DataMining)

# %% [markdown]
# ## 2. Instalación de Weka e interfaz
#
# La heramienta es multiplataforma, está disponible para Windows, Mac y GNU/Linux y se puede descargar desde: `https://www.cs.waikato.ac.nz/ml/weka/`
#
# ![image.png](data:image/png;base64,...)
#
# En este caso, dado que se utiliza software libre, se utilizó la tienda de software de Ubuntu para su descarga:
#
# ![Captura de pantalla-20220525190557-1197x675.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Ficheros .arff
# Nativamente Weka trabaja con un formato denominado arff , acrónimo de Attribute-Relation
# File Format. Este formato está compuesto por una estructura claramente diferenciada en tres partes:
#
# 1. Cabecera. Se define el nombre de la relación. Su formato es el siguiente:
#
# > `@relation <nombre-de-la-relación>`
# Donde `<nombre-de-la-relación>` es de tipo `String`*. Si dicho nombre contiene algún espacio será necesario expresarlo entrecomillado.
#
# 2. Declaraciones de atributos. En esta sección se declaran los atributos que compondrán nuestro archivo junto a su tipo. La sintaxis es la siguiente:
# @attribute `<nombre-del-atributo> <tipo>`
#
# > Donde `<nombre-del-atributo>` es de tipo `String` teniendo las mismas restricciones que el caso anterior. Weka acepta diversos tipos, estos son:
# >
# > a) NUMERIC Expresa números reales*
# >
# > b) INTEGER Expresa números enteros.
# >
# > c) DATE Expresa fechas, para ello este tipo debe ir precedido de una etiqueta de formato entrecomillada. La etiqueta de formato está compuesta por caracteres separadores (guiones y/o espacios) y unidades de tiempo:
# >
# >* dd Día.
# * MM Mes.
# * yyyy Año.
# * HH Horas.
# * mm Minutos.
# * ss Segundos.
# >
# > d) STRING Expresa cadenas de texto, con las restricciones del tipo String comentadas anteriormente.
# >
# > e) ENUMERADO El identificador de este tipo consiste en expresar entre llaves y separados por comas los posibles valores (caracteres o cadenas de caracteres) que puede tomar el atributo. Por ejemplo, si tenemos un atributo que indica el tiempo podría definirse: `@attribute tiempo {soleado,lluvioso,nublado}`
#
# 3. Sección de datos. Declaramos los datos que componen la relación separando entre comas los atributos y con saltos de línea las relaciones.

# %% [markdown]
# ## Ejercicio 1: Preprocesado
#
# **Dataset**: [Clima](https://storm.cis.fordham.edu/~gweiss/data-mining/weka-data/weather.arff)
#
# **Objetivo**: Preprocesado
#
# En este dataset sobre el clima tenemos como varios atributos como viento, humedad y temperatira; y tratamos como clase al atributo `play` que es el que queremos predecir. Es decir, a partir de los atributos dados, se desea saber si se puede jugar.
#
# Vemos que la tabla contiene valores numéricos y valores nominales
#
# El preprocesado permite observar qué relaciones existen, cantidad de atributos, instancias y pesos. En este caso:

# %% [markdown]
# ![Captura de pantalla-20220523010030-1021x767.png](data:image/png;base64,...)

# %% [markdown]
# Si nos vamos a la pestaña de `Edit` podemos ver la clase que queremos predecir, en este caso `play`
# ![Captura de pantalla-20220525194356-376x338.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicio 2: Visualización
#
# La pestaña visualización permite observar gráficamente el comportamineto de las variables y sus combinaciones.

# %% [markdown]
# ## Ejercicio 3: Filtros
#
# Caso 1
#
# **Dataset**: [Wheather nominal](https://storm.cis.fordham.edu/~gweiss/data-mining/weka-data/weather.nominal.arff)
#
# **Objetivo**: eliminar el atributo `humidity` del dataset
#
#
# Se puede aplicar filtros, lo cual corresponde a una modificación de los atributos de acuerdo a una serie de crietrios determinados para mejorar los resultados.
#
# Un ejemplo de ello podría ser eliminar una atributo, de decir podríamos darnos cuenta que uno de los atributos no es representativo o no es sano para el ejercicio, lo cual se puede realizar de dos maneras.
#
# La primera sería agregando un filtro que nos elimine ese atributo. Es ese caso vamos a la pestaña de `Filtros` `unsuperviced` `attribute` y buscamo el que se llama `Remove` y le damos click. Con esto lo que estamos haciendo es seleccionando el tipo de filtro a aplicar.
#
# Para indicarle qué debe remover, le damos click ahora en `Remove` e indicamos cuál es el índice del atributo que nos interesa eliminar.
#
# La segunda manera sería marcar el atributo a eliminar, y dar click en el área inferior en `Remove`.

# %% [markdown]
# Caso 2
#
# Objetivo: eliminar todos `high` del atributo `humidity`
#
# Es ese caso vamos a la pestaña de `Filtros` `unsuperviced` `instance` y buscamos el que se llama `RemoveWithValues` y le damos click. Con esto lo que estamos haciendo es seleccionando el tipo de filtro a aplicar.
#
#
# ![Captura de pantalla-20220525205419-471x484.png](data:image/png;base64,...)
#
#
# Procedemos a indicar el índice del atributo y el índice nominal
#
# ![Captura de pantalla-20220525205455-470x487.png](data:image/png;base64,...)
#
# Aplicamos
#
# ![Captura de pantalla-20220525205527-708x553.png](data:image/png;base64,...)
#
# Y procedemos a verificar el resultado
#
# ![Captura de pantalla-20220525205550-708x555.png](data:image/png;base64,...)
